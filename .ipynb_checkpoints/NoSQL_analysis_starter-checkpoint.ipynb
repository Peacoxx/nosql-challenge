# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
import pymongo
from pymongo import MongoClient
import pandas as pd
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# Load JSON data
file_path = '/Users/pamala/Documents/GitHub/nosql-challenge/resources/establishments.json'
data = pd.read_json(file_path)

# Verify the data
data.head()

# Convert the DataFrame to a dictionary and insert into MongoDB
data_dict = data.to_dict("records")
collection = db['establishments']
collection.insert_many(data_dict)
# Out:
# InsertManyResult([ObjectId('6678a4a23b90682d54a1a82d'), ObjectId('6678a4a23b90682d54a1a82e'), ObjectId('6678a4a23b90682d54a1a82f'), ObjectId('6678a4a23b90682d54a1a830'), ObjectId('6678a4a23b90682d54a1a831'), ObjectId('6678a4a23b90682d54a1a832'), ObjectId('6678a4a23b90682d54a1a833'), ObjectId('6678a4a23b90682d54a1a834'), ObjectId('6678a4a23b90682d54a1a835'), ObjectId('6678a4a23b90682d54a1a836'), ObjectId('6678a4a23b90682d54a1a837'), ObjectId('6678a4a23b90682d54a1a838'), ObjectId('6678a4a23b90682d54a1a839'), ObjectId('6678a4a23b90682d54a1a83a'), ObjectId('6678a4a23b90682d54a1a83b'), ObjectId('6678a4a23b90682d54a1a83c'), ObjectId('6678a4a23b90682d54a1a83d'), ObjectId('6678a4a23b90682d54a1a83e'), ObjectId('6678a4a23b90682d54a1a83f'), ObjectId('6678a4a23b90682d54a1a840'), ObjectId('6678a4a23b90682d54a1a841'), ObjectId('6678a4a23b90682d54a1a842'), ObjectId('6678a4a23b90682d54a1a843'), ObjectId('6678a4a23b90682d54a1a844'), ObjectId('6678a4a23b90682d54a1a845'), ObjectId('6678a4a23b90682d54a1a846'), ObjectId('6678a4a23b90682d54a1a847'), ObjectId('6678a4a23b90682d54a1a848'), ObjectId('6678a4a23b90682d54a1a849'), ObjectId('6678a4a23b90682d54a1a84a'), ObjectId('6678a4a23b90682d54a1a84b'), ObjectId('6678a4a23b90682d54a1a84c'), ObjectId('6678a4a23b90682d54a1a84d'), ObjectId('6678a4a23b90682d54a1a84e'), ObjectId('6678a4a23b90682d54a1a84f'), ObjectId('6678a4a23b90682d54a1a850'), ObjectId('6678a4a23b90682d54a1a851'), ObjectId('6678a4a23b90682d54a1a852'), ObjectId('6678a4a23b90682d54a1a853'), ObjectId('6678a4a23b90682d54a1a854'), ObjectId('6678a4a23b90682d54a1a855'), ObjectId('6678a4a23b90682d54a1a856'), ObjectId('6678a4a23b90682d54a1a857'), ObjectId('6678a4a23b90682d54a1a858'), ObjectId('6678a4a23b90682d54a1a859'), ObjectId('6678a4a23b90682d54a1a85a'), ObjectId('6678a4a23b90682d54a1a85b'), ObjectId('6678a4a23b90682d54a1a85c'), ObjectId('6678a4a23b90682d54a1a85d'), ObjectId('6678a4a23b90682d54a1a85e'), ObjectId('6678a4a23b90682d54a1a85f'), ObjectId('6678a4a23b90682d54a1a860'), ObjectId('6678a4a23b90682d54a1a861'), ObjectId('6678a4a23b90682d54a1a862'), ObjectId('6678a4a23b90682d54a1a863'), ObjectId('6678a4a23b90682d54a1a864'), ObjectId('6678a4a23b90682d54a1a865'), ObjectId('6678a4a23b90682d54a1a866'), ObjectId('6678a4a23b90682d54a1a867'), ObjectId('6678a4a23b90682d54a1a868'), ObjectId('6678a4a23b90682d54a1a869'), ObjectId('6678a4a23b90682d54a1a86a'), ObjectId('6678a4a23b90682d54a1a86b'), ObjectId('6678a4a23b90682d54a1a86c'), ObjectId('6678a4a23b90682d54a1a86d'), ObjectId('6678a4a23b90682d54a1a86e'), ObjectId('6678a4a23b90682d54a1a86f'), ObjectId('6678a4a23b90682d54a1a870'), ObjectId('6678a4a23b90682d54a1a871'), ObjectId('6678a4a23b90682d54a1a872'), ObjectId('6678a4a23b90682d54a1a873'), ObjectId('6678a4a23b90682d54a1a874'), ObjectId('6678a4a23b90682d54a1a875'), ObjectId('6678a4a23b90682d54a1a876'), ObjectId('6678a4a23b90682d54a1a877'), ObjectId('6678a4a23b90682d54a1a878'), ObjectId('6678a4a23b90682d54a1a879'), ObjectId('6678a4a23b90682d54a1a87a'), ObjectId('6678a4a23b90682d54a1a87b'), ObjectId('6678a4a23b90682d54a1a87c'), ObjectId('6678a4a23b90682d54a1a87d'), ObjectId('6678a4a23b90682d54a1a87e'), ObjectId('6678a4a23b90682d54a1a87f'), ObjectId('6678a4a23b90682d54a1a880'), ObjectId('6678a4a23b90682d54a1a881'), ObjectId('6678a4a23b90682d54a1a882'), ObjectId('6678a4a23b90682d54a1a883'), ObjectId('6678a4a23b90682d54a1a884'), ObjectId('6678a4a23b90682d54a1a885'), ObjectId('6678a4a23b90682d54a1a886'), ObjectId('6678a4a23b90682d54a1a887'), ObjectId('6678a4a23b90682d54a1a888'), ObjectId('6678a4a23b90682d54a1a889'), ObjectId('6678a4a23b90682d54a1a88a'), ObjectId('6678a4a23b90682d54a1a88b'), ObjectId('6678a4a23b90682d54a1a88c'), ObjectId('6678a4a23b90682d54a1a88d'), ObjectId('6678a4a23b90682d54a1a88e'), ObjectId('6678a4a23b90682d54a1a88f'), ObjectId('6678a4a23b90682d54a1a890'), ObjectId('6678a4a23b90682d54a1a891'), ObjectId('6678a4a23b90682d54a1a892'), ObjectId('6678a4a23b90682d54a1a893'), ObjectId('6678a4a23b90682d54a1a894'), ObjectId('6678a4a23b90682d54a1 ...

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Verify the import by printing the first document in the collection
pprint(collection.find_one())
# Out:
# {'AddressLine1': '1 The Droveway',
#  'AddressLine2': 'St Margarets Bay',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'FirstLight Bar & Café',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4587.64041272672,
#  'FHRSID': 1290215,
#  'LocalAuthorityBusinessID': 'PI/000083029',
#  'LocalAuthorityCode': '182',
#  'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#  'LocalAuthorityName': 'Dover',
#  'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT15 6DH',
#  'RatingDate': '2020-11-09T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6678a1a9c8c9ae191f6c2f25'),
#  'geocode': {'latitude': '51.150625', 'longitude': '1.378231'},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1290215',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}

# %%
# Find the establishments with a hygiene score of 20
query = {"scores.Hygiene": 20}

# Use count_documents to display the number of documents in the result
count = collection.count_documents(query)

# Display the first document in the results using pprint
print(f"Number of establishments with a hygiene score of 20: {count}")
# Out:
# Number of establishments with a hygiene score of 20: 82

# %%
# Convert the result to a Pandas DataFrame
results = collection.find(query)
df = pd.DataFrame(list(results))
# Display the number of rows in the DataFrame
num_rows = len(df)
print(f"Number of rows in the DataFrame: {num_rows}")

# Display the first 10 rows of the DataFrame
df.head(10)
# Out:
# Number of rows in the DataFrame: 82
#                         _id   FHRSID  ChangesByServerID  \
# 0  6678a1aac8c9ae191f6c4d3c   110681                  0
# 1  6678a1aac8c9ae191f6c50bf   612039                  0
# 2  6678a1aac8c9ae191f6c53c8   730933                  0
# 3  6678a1aac8c9ae191f6c55b3   172735                  0
# 4  6678a1aac8c9ae191f6c55c3   172953                  0
# 5  6678a1aac8c9ae191f6c5f69   512854                  0
# 6  6678a1aac8c9ae191f6c6182  1537089                  0
# 7  6678a1aac8c9ae191f6c76b0   155648                  0
# 8  6678a1aac8c9ae191f6c7af2  1012883                  0
# 9  6678a1aac8c9ae191f6c8306   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000023858              Seaford Pizza
# 4             PI/000024532              Golden Palace
# 5            12/00816/BUTH           Ashby's Butchers
# 6          22/00224/RESTUN  South Sea Express Cuisine
# 7              EH/00006058              Golden Palace
# 8         17/00110/MIXED/S             The Tulip Tree
# 9                    41811                      F & S
#
#                         BusinessType  BusinessTypeID           AddressLine1  \
# 0                    Caring Premises               5   5-6 Southfields Road
# 1                    Caring Premises               5              Hall Lane
# 2  Hotel/bed & breakfast/guest house            7842  53 Marine Parade East
# 3             Takeaway/sandwich shop            7844          4 High Street
# 4            Restaurant/Cafe/Canteen               1         5 South Street
# 5                  Retailers - other            4613   777 Southchurch Road
# 6            Restaurant/Cafe/Canteen               1    33 Alexandra Street
# 7             Takeaway/sandwich shop            7844          7 London Road
# 8            Restaurant/Cafe/Canteen               1          3 The Village
# 9                  Retailers - other            4613
#
#          AddressLine2 AddressLine3  ...  \
# 0          Eastbourne  East Sussex  ...
# 1  Walton-on-the-Naze        Essex  ...
# 2      Clacton On Sea        Essex  ...
# 3             Seaford  East Sussex  ...
# 4             Seaford  East Sussex  ...
# 5     Southend-On-Sea        Essex  ...
# 6     Southend-on-sea        Essex  ...
# 7            Rayleigh        Essex  ...
# 8       Chiddingstone         KENT  ...
# 9      81 Southernhay     Basildon  ...
#
#                       LocalAuthorityWebSite  \
# 0  http://www.eastbourne.gov.uk/foodratings
# 1             http://www.tendringdc.gov.uk/
# 2             http://www.tendringdc.gov.uk/
# 3       http://www.lewes-eastbourne.gov.uk/
# 4       http://www.lewes-eastbourne.gov.uk/
# 5                http://www.southend.gov.uk
# 6                http://www.southend.gov.uk
# 7                http://www.rochford.gov.uk
# 8              http://www.sevenoaks.gov.uk/
# 9                http://www.basildon.gov.uk
#
#               LocalAuthorityEmailAddress  \
# 0        Customerfirst@eastbourne.gov.uk
# 1             fhsadmin@tendringdc.gov.uk
# 2             fhsadmin@tendringdc.gov.uk
# 3    ehealth.ldc@lewes-eastbourne.gov.uk
# 4    ehealth.ldc@lewes-eastbourne.gov.uk
# 5    EnvironmentalHealth@southend.gov.uk
# 6    EnvironmentalHealth@southend.gov.uk
# 7       customerservices@rochford.gov.uk
# 8  environmental.health@sevenoaks.gov.uk
# 9                    ehs@basildon.gov.uk
#
#                                               scores SchemeType  \
# 0  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 1  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...       FHRS
# 2  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 3  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...       FHRS
# 4  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...       FHRS
# 5  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 6  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 7  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...       FHRS
# 8  {'Hygiene': 20, 'Structural': 5, 'ConfidenceIn...       FHRS
# 9  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
#
#                                              geocode RightToReply  \
# 0  {'longitude': '0.27694', 'latitude': '50.769705'}
# 1  {'longitude': '1.278721', 'latitude': '51.8575...
# 2  {'longitude': '1.15927', 'latitude': '51.789429'}
# 3  {'longitude': '0.10202', 'latitude': '50.770885'}
# 4  {'longitude': '0.101446', 'latitude': '50.7707...
# 5  {'longitude': '0.736349', 'latitude': '51.5414...
# 6  {'longitude': '0.7121671', 'latitude': '51.535...
# 7  {'longitude': '0.602364', 'latitude': '51.5915...
# 8  {'longitude': '0.146449998021126', 'latitude':...
# 9  {'longitude': '0.462307', 'latitude': '51.57005'}
#
#       Distance NewRatingPending  \
# 0  4613.888288            False
# 1  4617.965824            False
# 2  4619.656144            False
# 3  4620.421725            False
# 4  4620.437179            False
# 5  4625.565258            False
# 6  4626.200132            False
# 7  4632.276890            False
# 8  4633.934041            False
# 9  4636.552523            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
# 5  {'dataSource': None, 'extractDate': '0001-01-0...
# 6  {'dataSource': None, 'extractDate': '0001-01-0...
# 7  {'dataSource': None, 'extractDate': '0001-01-0...
# 8  {'dataSource': None, 'extractDate': '0001-01-0...
# 9  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'https://api.ratings....
# 1  [{'rel': 'self', 'href': 'https://api.ratings....
# 2  [{'rel': 'self', 'href': 'https://api.ratings....
# 3  [{'rel': 'self', 'href': 'https://api.ratings....
# 4  [{'rel': 'self', 'href': 'https://api.ratings....
# 5  [{'rel': 'self', 'href': 'https://api.ratings....
# 6  [{'rel': 'self', 'href': 'https://api.ratings....
# 7  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 8  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 9  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [10 rows x 28 columns]

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
query = {
    "LocalAuthorityName": "London",
    "RatingValue": {"$gte": "4"}
}

# Use count_documents to display the number of documents in the result
count = collection.count_documents(query)
# Display the first document in the results using pprint
print(f"Number of establishments with London as the Local Authority and RatingValue >= 4: {count}")
# Out:
# Number of establishments with London as the Local Authority and RatingValue >= 4: 0

# %%
# Convert the result to a Pandas DataFrame
results = collection.find(query)
df = pd.DataFrame(list(results))
# Display the number of rows in the DataFrame
num_rows = len(df)
print(f"Number of rows in the DataFrame: {num_rows}")
# Display the first 10 rows of the DataFrame
df.head(10)
# Out:
# Number of rows in the DataFrame: 0
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

degree_search = 0.01
latitude =
longitude =

query =
sort =
limit =

# Print the results

# %%
# Convert result to Pandas DataFrame

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that:
# 1. Matches establishments with a hygiene score of 0
# 2. Groups the matches by Local Authority
# 3. Sorts the matches from highest to lowest

# Print the number of documents in the result

# Print the first 10 results

# %%
# Convert the result to a Pandas DataFrame

# Display the number of rows in the DataFrame

# Display the first 10 rows of the DataFrame
